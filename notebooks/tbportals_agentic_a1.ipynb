# %% [markdown]
# # TB Portals — **Agentic 6-Rung Pipeline (headline run)**: mode `a1`
# Caches RAD-DINO patch-grid features, runs rungs `1 3 6 7` + agentic_best variants + spatial-cavity probe, **5 seeds × M=10**, saves heads. Download `agentic_a1.zip`.
# Attach only **tb-portals-cxr-pngs**; Internet **ON**; GPU T4.

# %% [markdown]
# ## 0 — Clone  *(restart kernel after any pull that changed .py)*

# %%
import os, sys, subprocess
REPO_URL = "https://github.com/mabdullahi7780/dl-project-codebase.git"
REPO_DIR = "/kaggle/working/dl-project-codebase"
BRANCH   = "cleaned-repo"
if os.path.isdir(REPO_DIR):
    subprocess.run(["git", "-C", REPO_DIR, "pull", "--ff-only"], check=True)
else:
    subprocess.run(["git", "clone", "--depth", "1", "--branch", BRANCH, REPO_URL, REPO_DIR], check=True)
for _p in (REPO_DIR, REPO_DIR + "/scripts"):
    if _p not in sys.path: sys.path.insert(0, _p)
print("repo ready at", REPO_DIR)
# Out:
# Cloning into '/kaggle/working/dl-project-codebase'...
# Updating files:  93% (433/465)
# repo ready at /kaggle/working/dl-project-codebase
# Updating files: 100% (465/465), done.

# %% [markdown]
# ## Install deps

# %%
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "-q",
                "transformers", "torchxrayvision", "pydicom", "pylibjpeg", "pylibjpeg-libjpeg"], check=False)
print("deps installed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 81.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 95.3 MB/s eta 0:00:00
# deps installed
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %% [markdown]
# ## Paths

# %%
import os
WORK          = "/kaggle/working"
REPO_DIR      = "/kaggle/working/dl-project-codebase"
DATASET       = "/kaggle/input/datasets/mabdullahi454/tb-portals-cxr-pngs"
KAGGLE_EXPORT = f"{DATASET}/kaggle_export"
PAPER_MANIFEST = f"{WORK}/tbportals_manifest_paper.csv"
MODE          = "a1"
BACKBONE      = "rad-dino"
FEATURES      = f"{WORK}/features_{BACKBONE}_grid7.npz"
# (a1) primary cache IS the grid; no separate grid cache needed.
print("MODE:", MODE, "| KAGGLE_EXPORT:", os.path.isdir(KAGGLE_EXPORT), "| primary features ->", FEATURES)
# Out:
# MODE: a1 | KAGGLE_EXPORT: True | primary features -> /kaggle/working/features_rad-dino_grid7.npz

# %% [markdown]
# ## 1 — Build the 5,010-image manifest (Kantipudi Table 1)

# %%
import sys, pandas as pd
from pathlib import Path
if REPO_DIR + "/scripts" not in sys.path: sys.path.insert(0, REPO_DIR + "/scripts")
from build_paper_manifest import subsample, PAPER_TOTAL
raw = pd.read_csv(f"{KAGGLE_EXPORT}/manifest.csv",
                  dtype={"image_id": str, "patient_id": str, "country": str})
raw["image_path"] = raw["image_path"].apply(
    lambda p: p if str(p).startswith("/") else f"{KAGGLE_EXPORT}/{p}")
paper_df = subsample(raw, seed=42)
paper_df["image_id"] = paper_df["image_path"].apply(lambda p: Path(str(p)).stem)
paper_df.to_csv(PAPER_MANIFEST, index=False)
print(f"Paper manifest: {len(paper_df)} images (target {PAPER_TOTAL}) -> {PAPER_MANIFEST}")
# Out:
# country       need_c  have_c  need_n  have_n
# Georgia          713    1298     701    1108
# Belarus          254     285     798     894
# Ukraine          500    1206     816    1775
# Kazakhstan       159     304     240     384
# Romania          143     233      77     171
# Moldova          193     278     396     527
# Azerbaijan         5       7      12      18
# India              0       6       3      12
# Paper manifest: 5010 images (target 5010) -> /kaggle/working/tbportals_manifest_paper.csv

# %% [markdown]
# ## 2 — Cache primary features (one-time; idempotent)

# %%
import os, sys
if REPO_DIR + "/scripts" not in sys.path: sys.path.insert(0, REPO_DIR + "/scripts")
if os.path.isfile(FEATURES):
    print("primary features already cached ->", FEATURES)
else:
    from cache_features import main as cache_main
    cache_main(["--manifest", PAPER_MANIFEST, "--out", FEATURES,
                "--backbone", BACKBONE, "--patch-grid", "7", "--batch-size", "32"])
# Out:
# [cache] backbone=rad-dino device=cuda patch_grid=7
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# preprocessor_config.json:   0%|          | 0.00/756 [00:00<?, ?B/s]
# The image processor of type `BitImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json:   0%|          | 0.00/879 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]
# [cache] feature dim = 768
# [cache] 320/5010
# [cache] 640/5010
# [cache] 960/5010
# [cache] 1280/5010
# [cache] 1600/5010
# [cache] 1920/5010
# [cache] 2240/5010
# [cache] 2560/5010
# [cache] 2880/5010
# [cache] 3200/5010
# [cache] 3520/5010
# [cache] 3840/5010
# [cache] 4160/5010
# [cache] 4480/5010
# [cache] 4800/5010
# [cache] wrote features (5010, 49, 768) -> /kaggle/working/features_rad-dino_grid7.npz

# %% [markdown]
# ## 2b — Cache patch-grid features (for the spatial cavity head)

# %%
# (a1) skipped
print('a1 mode: grid is the primary cache, skipping aux grid cache.')
# Out:
# a1 mode: grid is the primary cache, skipping aux grid cache.

# %% [markdown]
# ## 3 — Run the rung ladder for mode `a1` (rungs 1 3 6 7, 5 seeds, M=10)

# %%
from src.training.train_agentic import main as agentic_main
args = ["--features", FEATURES, "--manifest", PAPER_MANIFEST,
        "--mode", MODE, "--out-dir", f"{WORK}/agentic_{MODE}",
        "--rungs", '1', '3', '6', '7',
        "--seeds", '0', '1', '2', '3', '4',
        "--ensemble-m", "10",
        "--held-outs", "Romania", "Moldova", "Kazakhstan",
        "--save-heads"]
agentic_main(args)
# Out:
# [agentic] device=cuda mode=a1 dim=768 feat=grid grid_available=True rungs=[1, 3, 6, 7] seeds=[0, 1, 2, 3, 4] M=10
# [agentic] 12 configs: ['rung1_mse', 'rung1_bmc', 'rung3_retrieval', 'rung6_conformal', 'rung7_calibrate_lin', 'rung7_calibrate_iso', 'agentic_best', 'agentic_v2_lin', 'agentic_v2_iso', 'rung4b_spatial_cavity', 'agentic_best_spatcav', 'stacked_legacy']
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [a1|rung1_mse] Romania s0  MAE=19.43 CI[17.4,21.6] r=0.650 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [a1|rung1_mse] Romania s1  MAE=20.28 CI[18.1,22.7] r=0.632 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|rung1_mse] Romania s2  MAE=19.83 CI[17.6,22.2] r=0.653 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|rung1_mse] Romania s3  MAE=19.63 CI[17.6,21.9] r=0.663 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [a1|rung1_mse] Romania s4  MAE=21.28 CI[19.1,23.6] r=0.598 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [a1|rung1_mse] Moldova s0  MAE=23.25 CI[21.5,25.1] r=0.796 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [a1|rung1_mse] Moldova s1  MAE=21.52 CI[19.8,23.2] r=0.820 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [a1|rung1_mse] Moldova s2  MAE=21.78 CI[20.2,23.3] r=0.805 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [a1|rung1_mse] Moldova s3  MAE=25.43 CI[23.7,27.2] r=0.771 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [a1|rung1_mse] Moldova s4  MAE=19.81 CI[18.5,21.2] r=0.804 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [a1|rung1_mse] Kazakhstan s0  MAE=20.04 CI[18.2,22.1] r=0.666 a=0.00 | base 21.87 paper 22.13 -> within-noise
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [a1|rung1_mse] Kazakhstan s1  MAE=20.17 CI[18.3,22.1] r=0.681 a=0.00 | base 21.87 paper 22.13 -> within-noise
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|rung1_mse] Kazakhstan s2  MAE=19.28 CI[17.6,21.2] r=0.697 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|rung1_mse] Kazakhstan s3  MAE=18.78 CI[16.9,20.8] r=0.700 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [a1|rung1_mse] Kazakhstan s4  MAE=17.84 CI[16.3,19.5] r=0.752 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [a1|r
a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [a1|agentic_best] Moldova s0  MAE=24.87 CI[23.0,26.7] r=0.792 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [a1|agentic_best] Moldova s1  MAE=22.63 CI[20.9,24.3] r=0.817 a=0.20 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [a1|agentic_best] Moldova s2  MAE=20.75 CI[19.2,22.2] r=0.814 a=0.10 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [a1|agentic_best] Moldova s3  MAE=24.06 CI[22.4,25.7] r=0.778 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [a1|agentic_best] Moldova s4  MAE=20.01 CI[18.7,21.4] r=0.807 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [a1|agentic_best] Kazakhstan s0  MAE=19.65 CI[17.9,21.8] r=0.684 a=0.20 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [a1|agentic_best] Kazakhstan s1  MAE=20.00 CI[18.2,21.9] r=0.686 a=0.20 | base 21.87 paper 22.13 -> within-noise
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_best] Kazakhstan s2  MAE=19.07 CI[17.3,20.9] r=0.703 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_best] Kazakhstan s3  MAE=18.69 CI[16.7,20.7] r=0.702 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [a1|agentic_best] Kazakhstan s4  MAE=18.06 CI[16.4,19.7] r=0.748 a=0.30 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_lin] Romania s0  MAE=19.47 CI[17.3,21.8] r=0.647 a=0.20 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_lin] Romania s1  MAE=20.34 CI[18.1,22.7] r=0.620 a=0.35 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_lin] Romania s2  MAE=19.91 CI[17.6,22.3] r=0.647 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_lin] Romania s3  MAE=19.30 CI[17.2,21.6] r=0.652 a=0.30 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_lin] Romania s4  MAE=21.15 CI[18.8,23.7] r=0.594 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_lin] Moldova s0  MAE=23.77 CI[22.0,25.5] r=0.790 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_lin] Moldova s1  MAE=21.57 CI[19.8,23.2] r=0.815 a=0.20 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_lin] Moldova s2  MAE=20.47 CI[19.0,21.9] r=0.812 a=0.10 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_lin] Moldova s3  MAE=23.22 CI[21.5,24.9] r=0.777 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_lin] Moldova s4  MAE=20.36 CI[19.0,21.8] r=0.803 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_lin] Kazakhstan s0  MAE=19.73 CI[18.0,21.8] r=0.683 a=0.20 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_lin] Kazakhstan s1  MAE=20.02 CI[18.2,21.9] r=0.684 a=0.20 | base 21.87 paper 22.13 -> within-noise
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_lin] Kazakhstan s2  MAE=19.12 CI[17.4,20.9] r=0.701 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_lin] Kazakhstan s3  MAE=18.76 CI[16.8,20.7] r=0.700 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_lin] Kazakhstan s4  MAE=18.26 CI[16.6,19.9] r=0.744 a=0.30 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_iso] Romania s0  MAE=19.56 CI[17.4,21.9] r=0.646 a=0.20 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_iso] Romania s1  MAE=20.43 CI[18.2,22.8] r=0.617 a=0.35 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_iso] Romania s2  MAE=20.24 CI[18.0,22.7] r=0.642 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_iso] Romania s3  MAE=19.53 CI[17.3,21.9] r=0.644 a=0.30 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [a1|agentic_v2_iso] Romania s4  MAE=21.38 CI[19.0,23.8] r=0.591 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_iso] Moldova s0  MAE=23.84 CI[22.0,25.7] r=0.785 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_iso] Moldova s1  MAE=21.72 CI[20.0,23.4] r=0.812 a=0.20 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_iso] Moldova s2  MAE=20.56 CI[19.1,22.0] r=0.807 a=0.10 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_iso] Moldova s3  MAE=23.37 CI[21.7,25.1] r=0.775 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [a1|agentic_v2_iso] Moldova s4  MAE=20.40 CI[19.0,21.8] r=0.804 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_iso] Kazakhstan s0  MAE=19.70 CI[18.0,21.7] r=0.682 a=0.20 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_iso] Kazakhstan s1  MAE=20.00 CI[18.1,21.9] r=0.682 a=0.20 | base 21.87 paper 22.13 -> within-noise
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_iso] Kazakhstan s2  MAE=19.13 CI[17.4,21.0] r=0.700 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_iso] Kazakhstan s3  MAE=18.65 CI[16.8,20.6] r=0.704 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [a1|agentic_v2_iso] Kazakhstan s4  MAE=18.12 CI[16.5,19.8] r=0.749 a=0.30 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [a1|rung4b_spatial_cavity] Romania s0  MAE=19.45 CI[17.3,21.6] r=0.697 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [a1|rung4b_spatial_cavity] Romania s1  MAE=19.98 CI[17.8,22.2] r=0.686 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|rung4b_spatial_cavity] Romania s2  MAE=20.99 CI[18.8,23.4] r=0.669 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|rung4b_spatial_cavity] Romania s3  MAE=19.65 CI[17.6,21.9] r=0.703 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [a1|rung4b_spatial_cavity] Romania s4  MAE=19.85 CI[17.7,22.3] r=0.684 a=0.00 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [a1|rung4b_spatial_cavity] Moldova s0  MAE=23.04 CI[21.5,24.7] r=0.817 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [a1|rung4b_spatial_cavity] Moldova s1  MAE=23.33 CI[21.8,24.9] r=0.803 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [a1|rung4b_spatial_cavity] Moldova s2  MAE=20.18 CI[18.8,21.5] r=0.801 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [a1|rung4b_spatial_cavity] Moldova s3  MAE=21.22 CI[19.7,22.7] r=0.816 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [a1|rung4b_spatial_cavity] Moldova s4  MAE=19.20 CI[18.0,20.7] r=0.811 a=0.00 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [a1|rung4b_spatial_cavity] Kazakhstan s0  MAE=18.25 CI[16.4,20.1] r=0.739 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [a1|rung4b_spatial_cavity] Kazakhstan s1  MAE=18.46 CI[16.6,20.2] r=0.732 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|rung4b_spatial_cavity] Kazakhstan s2  MAE=17.59 CI[15.8,19.3] r=0.761 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|rung4b_spatial_cavity] Kazakhstan s3  MAE=17.55 CI[15.8,19.2] r=0.752 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [a1|rung4b_spatial_cavity] Kazakhstan s4  MAE=17.23 CI[15.6,18.9] r=0.769 a=0.00 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [a1|agentic_best_spatcav] Romania s0  MAE=19.37 CI[17.2,21.6] r=0.691 a=0.20 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [a1|agentic_best_spatcav] Romania s1  MAE=19.42 CI[17.5,21.5] r=0.677 a=0.35 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|agentic_best_spatcav] Romania s2  MAE=20.09 CI[17.9,22.4] r=0.667 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|agentic_best_spatcav] Romania s3  MAE=19.46 CI[17.4,21.6] r=0.687 a=0.30 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [a1|agentic_best_spatcav] Romania s4  MAE=19.91 CI[17.8,22.3] r=0.674 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [a1|agentic_best_spatcav] Moldova s0  MAE=22.17 CI[20.6,23.8] r=0.813 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [a1|agentic_best_spatcav] Moldova s1  MAE=21.42 CI[19.9,22.9] r=0.804 a=0.20 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [a1|agentic_best_spatcav] Moldova s2  MAE=20.02 CI[18.6,21.4] r=0.800 a=0.10 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [a1|agentic_best_spatcav] Moldova s3  MAE=21.39 CI[19.9,22.9] r=0.808 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [a1|agentic_best_spatcav] Moldova s4  MAE=20.26 CI[18.9,21.8] r=0.799 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [a1|agentic_best_spatcav] Kazakhstan s0  MAE=18.20 CI[16.4,20.0] r=0.736 a=0.20 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [a1|agentic_best_spatcav] Kazakhstan s1  MAE=18.50 CI[16.7,20.2] r=0.732 a=0.20 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_best_spatcav] Kazakhstan s2  MAE=17.59 CI[15.9,19.2] r=0.758 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|agentic_best_spatcav] Kazakhstan s3  MAE=17.50 CI[15.9,19.1] r=0.755 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [a1|agentic_best_spatcav] Kazakhstan s4  MAE=17.66 CI[16.1,19.3] r=0.757 a=0.30 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [a1|stacked_legacy] Romania s0  MAE=19.38 CI[17.1,21.8] r=0.651 a=0.20 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [a1|stacked_legacy] Romania s1  MAE=20.37 CI[18.1,22.8] r=0.621 a=0.35 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|stacked_legacy] Romania s2  MAE=19.92 CI[17.6,22.4] r=0.648 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [a1|stacked_legacy] Romania s3  MAE=19.31 CI[17.2,21.7] r=0.653 a=0.30 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [a1|stacked_legacy] Romania s4  MAE=21.23 CI[18.8,23.6] r=0.594 a=0.25 | base 26.84 paper 23.83 -> BEATS
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [a1|stacked_legacy] Moldova s0  MAE=24.87 CI[23.0,26.7] r=0.792 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [a1|stacked_legacy] Moldova s1  MAE=22.63 CI[20.9,24.3] r=0.817 a=0.20 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [a1|stacked_legacy] Moldova s2  MAE=20.75 CI[19.2,22.2] r=0.814 a=0.10 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [a1|stacked_legacy] Moldova s3  MAE=24.06 CI[22.4,25.7] r=0.778 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [a1|stacked_legacy] Moldova s4  MAE=20.01 CI[18.7,21.4] r=0.807 a=0.25 | base 32.76 paper 24.44 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [a1|stacked_legacy] Kazakhstan s0  MAE=19.65 CI[17.9,21.8] r=0.684 a=0.20 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [a1|stacked_legacy] Kazakhstan s1  MAE=20.00 CI[18.2,21.9] r=0.686 a=0.20 | base 21.87 paper 22.13 -> within-noise
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|stacked_legacy] Kazakhstan s2  MAE=19.07 CI[17.3,20.9] r=0.703 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [a1|stacked_legacy] Kazakhstan s3  MAE=18.69 CI[16.7,20.7] r=0.702 a=0.25 | base 21.87 paper 22.13 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [a1|stacked_legacy] Kazakhstan s4  MAE=18.06 CI[16.4,19.7] r=0.748 a=0.30 | base 21.87 paper 22.13 -> BEATS
#
# [agentic] mean Timika MAE per rung x country (mode=a1):
#   rung1_mse          Rom=20.09/0.64 Mol=22.36/0.80 Kaz=19.22/0.70
#   rung1_bmc          Rom=20.34/0.65 Mol=23.09/0.81 Kaz=18.96/0.71
#   rung3_retrieval    Rom=20.16/0.63 Mol=22.94/0.80 Kaz=19.14/0.70
#   rung6_conformal    Rom=20.11/0.65 Mol=22.49/0.81 Kaz=18.97/0.71
#   rung7_calibrate_lin Rom=20.06/0.64 Mol=21.73/0.80 Kaz=19.00/0.70
#   rung7_calibrate_iso Rom=20.23/0.63 Mol=21.82/0.80 Kaz=19.00/0.70
#   agentic_best       Rom=20.04/0.63 Mol=22.46/0.80 Kaz=19.09/0.70
#   agentic_v2_lin     Rom=20.03/0.63 Mol=21.88/0.80 Kaz=19.18/0.70
#   agentic_v2_iso     Rom=20.23/0.63 Mol=21.98/0.80 Kaz=19.12/0.70
#   rung4b_spatial_cavity Rom=19.98/0.69 Mol=21.40/0.81 Kaz=17.81/0.75
#   agentic_best_spatcav Rom=19.65/0.68 Mol=21.05/0.80 Kaz=17.89/0.75
#   stacked_legacy     Rom=20.04/0.63 Mol=22.46/0.80 Kaz=19.09/0.70
#
# [agentic] -> /kaggle/working/agentic_a1/results_agentic_a1.csv

# %% [markdown]
# ## 4 — Save (download → baseline_runs/agentic_runs/)

# %%
import os, shutil
src = f"{WORK}/agentic_{MODE}"
try: shutil.copy(FEATURES, f"{src}/{os.path.basename(FEATURES)}")
except Exception as e: print("primary cache copy skipped:", e)
zip_path = shutil.make_archive(f"{WORK}/agentic_{MODE}", "zip", src)
print("Saved ->", zip_path)
print("Contents include: results_agentic_*.csv, preds_*.csv, heads/*.pt, features_*.npz")
# Out:
# Saved -> /kaggle/working/agentic_a1.zip
# Contents include: results_agentic_*.csv, preds_*.csv, heads/*.pt, features_*.npz
