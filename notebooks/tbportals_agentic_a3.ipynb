# %% [markdown]
# # TB Portals — **Agentic 6-Rung Pipeline (headline run)**: mode `fusion`
# Caches RAD-DINO CLS+patch-grid features, runs rungs `1 2 3 5 6 7` + agentic_best variants + spatial-cavity probe, **5 seeds × M=10**, saves heads. Download `agentic_fusion.zip`.
# Attach only **tb-portals-cxr-pngs**; Internet **ON**; GPU T4.

# %% [markdown]
# ## 0 — Clone  *(restart kernel after any pull that changed .py)*

# %%
import os, sys, subprocess
REPO_URL = "https://github.com/mabdullahi7780/dl-project-codebase.git"
REPO_DIR = "/kaggle/working/dl-project-codebase"
BRANCH   = "cleaned-repo"
if os.path.isdir(REPO_DIR):
    subprocess.run(["git", "-C", REPO_DIR, "pull", "--ff-only"], check=True)
else:
    subprocess.run(["git", "clone", "--depth", "1", "--branch", BRANCH, REPO_URL, REPO_DIR], check=True)
for _p in (REPO_DIR, REPO_DIR + "/scripts"):
    if _p not in sys.path: sys.path.insert(0, _p)
print("repo ready at", REPO_DIR)
# Out:
# Cloning into '/kaggle/working/dl-project-codebase'...
# Updating files:  64% (298/465)
# repo ready at /kaggle/working/dl-project-codebase
# Updating files: 100% (465/465), done.

# %% [markdown]
# ## Install deps

# %%
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "-q",
                "transformers", "torchxrayvision", "pydicom", "pylibjpeg", "pylibjpeg-libjpeg"], check=False)
print("deps installed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 64.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 100.7 MB/s eta 0:00:00
# deps installed
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %% [markdown]
# ## Paths

# %%
import os
WORK          = "/kaggle/working"
REPO_DIR      = "/kaggle/working/dl-project-codebase"
DATASET       = "/kaggle/input/datasets/mabdullahi454/tb-portals-cxr-pngs"
KAGGLE_EXPORT = f"{DATASET}/kaggle_export"
PAPER_MANIFEST = f"{WORK}/tbportals_manifest_paper.csv"
MODE          = "fusion"
BACKBONE      = "rad-dino"
FEATURES      = f"{WORK}/features_{BACKBONE}_cls.npz"
FEATURES_GRID = f"{WORK}/features_{BACKBONE}_grid7.npz"
print("aux grid features ->", FEATURES_GRID)
print("MODE:", MODE, "| KAGGLE_EXPORT:", os.path.isdir(KAGGLE_EXPORT), "| primary features ->", FEATURES)
# Out:
# aux grid features -> /kaggle/working/features_rad-dino_grid7.npz
# MODE: fusion | KAGGLE_EXPORT: True | primary features -> /kaggle/working/features_rad-dino_cls.npz

# %% [markdown]
# ## 1 — Build the 5,010-image manifest (Kantipudi Table 1)

# %%
import sys, pandas as pd
from pathlib import Path
if REPO_DIR + "/scripts" not in sys.path: sys.path.insert(0, REPO_DIR + "/scripts")
from build_paper_manifest import subsample, PAPER_TOTAL
raw = pd.read_csv(f"{KAGGLE_EXPORT}/manifest.csv",
                  dtype={"image_id": str, "patient_id": str, "country": str})
raw["image_path"] = raw["image_path"].apply(
    lambda p: p if str(p).startswith("/") else f"{KAGGLE_EXPORT}/{p}")
paper_df = subsample(raw, seed=42)
paper_df["image_id"] = paper_df["image_path"].apply(lambda p: Path(str(p)).stem)
paper_df.to_csv(PAPER_MANIFEST, index=False)
print(f"Paper manifest: {len(paper_df)} images (target {PAPER_TOTAL}) -> {PAPER_MANIFEST}")
# Out:
# country       need_c  have_c  need_n  have_n
# Georgia          713    1298     701    1108
# Belarus          254     285     798     894
# Ukraine          500    1206     816    1775
# Kazakhstan       159     304     240     384
# Romania          143     233      77     171
# Moldova          193     278     396     527
# Azerbaijan         5       7      12      18
# India              0       6       3      12
# Paper manifest: 5010 images (target 5010) -> /kaggle/working/tbportals_manifest_paper.csv

# %% [markdown]
# ## 2 — Cache primary features (one-time; idempotent)

# %%
import os, sys
if REPO_DIR + "/scripts" not in sys.path: sys.path.insert(0, REPO_DIR + "/scripts")
if os.path.isfile(FEATURES):
    print("primary features already cached ->", FEATURES)
else:
    from cache_features import main as cache_main
    cache_main(["--manifest", PAPER_MANIFEST, "--out", FEATURES,
                "--backbone", BACKBONE, "--batch-size", "32"])
# Out:
# [cache] backbone=rad-dino device=cuda patch_grid=off (CLS)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# preprocessor_config.json:   0%|          | 0.00/756 [00:00<?, ?B/s]
# The image processor of type `BitImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json:   0%|          | 0.00/879 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]
# [cache] feature dim = 768
# [cache] 320/5010
# [cache] 640/5010
# [cache] 960/5010
# [cache] 1280/5010
# [cache] 1600/5010
# [cache] 1920/5010
# [cache] 2240/5010
# [cache] 2560/5010
# [cache] 2880/5010
# [cache] 3200/5010
# [cache] 3520/5010
# [cache] 3840/5010
# [cache] 4160/5010
# [cache] 4480/5010
# [cache] 4800/5010
# [cache] wrote features (5010, 768) -> /kaggle/working/features_rad-dino_cls.npz

# %% [markdown]
# ## 2b — Cache patch-grid features (for the spatial cavity head)

# %%
if os.path.isfile(FEATURES_GRID):
    print("grid features already cached ->", FEATURES_GRID)
else:
    from cache_features import main as cache_main
    cache_main(["--manifest", PAPER_MANIFEST, "--out", FEATURES_GRID,
                "--backbone", BACKBONE, "--patch-grid", "7", "--batch-size", "32"])
# Out:
# [cache] backbone=rad-dino device=cuda patch_grid=7
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]
# [cache] feature dim = 768
# [cache] 320/5010
# [cache] 640/5010
# [cache] 960/5010
# [cache] 1280/5010
# [cache] 1600/5010
# [cache] 1920/5010
# [cache] 2240/5010
# [cache] 2560/5010
# [cache] 2880/5010
# [cache] 3200/5010
# [cache] 3520/5010
# [cache] 3840/5010
# [cache] 4160/5010
# [cache] 4480/5010
# [cache] 4800/5010
# [cache] wrote features (5010, 49, 768) -> /kaggle/working/features_rad-dino_grid7.npz

# %% [markdown]
# ## 3 — Run the rung ladder for mode `fusion` (rungs 1 2 3 5 6 7, 5 seeds, M=10)

# %%
from src.training.train_agentic import main as agentic_main
args = ["--features", FEATURES, "--manifest", PAPER_MANIFEST,
        "--mode", MODE, "--out-dir", f"{WORK}/agentic_{MODE}",
        "--rungs", '1', '2', '3', '5', '6', '7',
        "--seeds", '0', '1', '2', '3', '4',
        "--ensemble-m", "10",
        "--held-outs", "Romania", "Moldova", "Kazakhstan",
        "--save-heads"]
args += ["--features-grid", FEATURES_GRID]
agentic_main(args)
# Out:
# [agentic] aux grid cache loaded: dim=768 P=49
# [agentic] device=cuda mode=fusion dim=768 feat=CLS grid_available=True rungs=[1, 2, 3, 5, 6, 7] seeds=[0, 1, 2, 3, 4] M=10
# [agentic] 15 configs: ['rung1_mse', 'rung1_bmc', 'rung2_tta', 'rung3_retrieval', 'rung5_moe', 'rung6_conformal', 'rung7_calibrate_lin', 'rung7_calibrate_iso', 'agentic_best', 'agentic_v2_lin', 'agentic_v2_iso', 'agentic_best_tta', 'rung4b_spatial_cavity', 'agentic_best_spatcav', 'stacked_legacy']
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [fusion|r
a=0.00 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|rung7_calibrate_iso] Kazakhstan s3  MAE=18.52 CI[17.0,20.1] r=0.749 a=0.00 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [fusion|rung7_calibrate_iso] Kazakhstan s4  MAE=18.78 CI[17.3,20.2] r=0.771 a=0.00 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [fusion|agentic_best] Romania s0  MAE=19.68 CI[17.6,21.8] r=0.659 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [fusion|agentic_best] Romania s1  MAE=20.09 CI[18.2,21.9] r=0.650 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_best] Romania s2  MAE=19.94 CI[18.1,22.0] r=0.658 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_best] Romania s3  MAE=19.09 CI[17.2,21.0] r=0.689 a=0.10 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [fusion|agentic_best] Romania s4  MAE=20.00 CI[18.1,22.0] r=0.653 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [fusion|agentic_best] Moldova s0  MAE=22.54 CI[20.8,24.2] r=0.821 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [fusion|agentic_best] Moldova s1  MAE=21.54 CI[19.9,23.2] r=0.801 a=0.15 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [fusion|agentic_best] Moldova s2  MAE=21.80 CI[20.3,23.3] r=0.794 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [fusion|agentic_best] Moldova s3  MAE=21.44 CI[19.8,23.0] r=0.796 a=0.10 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [fusion|agentic_best] Moldova s4  MAE=22.21 CI[20.5,23.9] r=0.815 a=0.20 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [fusion|agentic_best] Kazakhstan s0  MAE=17.14 CI[15.7,18.6] r=0.795 a=0.15 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [fusion|agentic_best] Kazakhstan s1  MAE=16.42 CI[14.9,17.9] r=0.805 a=0.25 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|agentic_best] Kazakhstan s2  MAE=17.05 CI[15.6,18.5] r=0.786 a=0.20 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|agentic_best] Kazakhstan s3  MAE=17.97 CI[16.5,19.5] r=0.764 a=0.10 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [fusion|agentic_best] Kazakhstan s4  MAE=17.79 CI[16.4,19.2] r=0.784 a=0.15 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_lin] Romania s0  MAE=19.64 CI[17.7,21.5] r=0.653 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_lin] Romania s1  MAE=20.28 CI[18.5,22.0] r=0.647 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_lin] Romania s2  MAE=20.03 CI[18.2,22.0] r=0.654 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_lin] Romania s3  MAE=19.16 CI[17.4,21.0] r=0.686 a=0.10 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_lin] Romania s4  MAE=20.06 CI[18.2,22.0] r=0.647 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2_lin] Moldova s0  MAE=22.94 CI[21.2,24.7] r=0.820 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2_lin] Moldova s1  MAE=21.90 CI[20.4,23.5] r=0.793 a=0.15 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2_lin] Moldova s2  MAE=22.09 CI[20.5,23.6] r=0.791 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2_lin] Moldova s3  MAE=21.61 CI[20.1,23.1] r=0.787 a=0.10 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2_lin] Moldova s4  MAE=22.69 CI[21.0,24.4] r=0.815 a=0.20 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [fusion|agentic_v2_lin] Kazakhstan s0  MAE=17.75 CI[16.3,19.1] r=0.792 a=0.15 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [fusion|agentic_v2_lin] Kazakhstan s1  MAE=16.61 CI[15.1,18.0] r=0.800 a=0.25 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|agentic_v2_lin] Kazakhstan s2  MAE=17.63 CI[16.2,19.1] r=0.784 a=0.20 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|agentic_v2_lin] Kazakhstan s3  MAE=18.37 CI[16.8,19.9] r=0.752 a=0.10 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [fusion|agentic_v2_lin] Kazakhstan s4  MAE=18.57 CI[17.1,20.0] r=0.774 a=0.15 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_iso] Romania s0  MAE=19.62 CI[17.7,21.6] r=0.658 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_iso] Romania s1  MAE=20.13 CI[18.3,21.9] r=0.652 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_iso] Romania s2  MAE=20.13 CI[18.3,22.1] r=0.653 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_iso] Romania s3  MAE=19.20 CI[17.4,21.1] r=0.688 a=0.10 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [fusion|agentic_v2_iso] Romania s4  MAE=20.09 CI[18.2,22.1] r=0.646 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2_iso] Moldova s0  MAE=23.24 CI[21.5,25.0] r=0.817 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2_iso] Moldova s1  MAE=22.04 CI[20.4,23.8] r=0.796 a=0.15 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [fusion|agentic_v2
a=0.00 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|rung4b_spatial_cavity] Kazakhstan s2  MAE=16.97 CI[15.6,18.5] r=0.792 a=0.00 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|rung4b_spatial_cavity] Kazakhstan s3  MAE=16.38 CI[14.9,17.9] r=0.796 a=0.00 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [fusion|rung4b_spatial_cavity] Kazakhstan s4  MAE=17.16 CI[15.6,18.6] r=0.790 a=0.00 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [fusion|agentic_best_spatcav] Romania s0  MAE=18.79 CI[16.8,20.7] r=0.698 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [fusion|agentic_best_spatcav] Romania s1  MAE=19.10 CI[17.3,21.0] r=0.687 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_best_spatcav] Romania s2  MAE=19.45 CI[17.5,21.4] r=0.685 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|agentic_best_spatcav] Romania s3  MAE=18.52 CI[16.7,20.4] r=0.710 a=0.10 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [fusion|agentic_best_spatcav] Romania s4  MAE=19.74 CI[17.7,21.8] r=0.671 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [fusion|agentic_best_spatcav] Moldova s0  MAE=22.28 CI[20.5,23.9] r=0.827 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [fusion|agentic_best_spatcav] Moldova s1  MAE=21.06 CI[19.5,22.6] r=0.819 a=0.15 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [fusion|agentic_best_spatcav] Moldova s2  MAE=21.21 CI[19.7,22.7] r=0.808 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [fusion|agentic_best_spatcav] Moldova s3  MAE=21.20 CI[19.7,22.7] r=0.808 a=0.10 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [fusion|agentic_best_spatcav] Moldova s4  MAE=22.21 CI[20.5,23.9] r=0.812 a=0.20 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [fusion|agentic_best_spatcav] Kazakhstan s0  MAE=16.94 CI[15.4,18.4] r=0.802 a=0.15 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [fusion|agentic_best_spatcav] Kazakhstan s1  MAE=16.50 CI[15.1,17.9] r=0.805 a=0.25 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|agentic_best_spatcav] Kazakhstan s2  MAE=16.68 CI[15.2,18.2] r=0.797 a=0.20 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|agentic_best_spatcav] Kazakhstan s3  MAE=16.46 CI[15.0,17.9] r=0.799 a=0.10 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [fusion|agentic_best_spatcav] Kazakhstan s4  MAE=17.13 CI[15.7,18.6] r=0.791 a=0.15 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Romania: train=3832 val=958 test=220 (train/val patients 3618/904).
# [fusion|stacked_legacy] Romania s0  MAE=19.68 CI[17.6,21.8] r=0.659 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3836 val=954 test=220 (train/val patients 3618/904).
# [fusion|stacked_legacy] Romania s1  MAE=20.09 CI[18.2,21.9] r=0.650 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|stacked_legacy] Romania s2  MAE=19.94 CI[18.1,22.0] r=0.658 a=0.15 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3843 val=947 test=220 (train/val patients 3618/904).
# [fusion|stacked_legacy] Romania s3  MAE=19.09 CI[17.2,21.0] r=0.689 a=0.10 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Romania: train=3839 val=951 test=220 (train/val patients 3618/904).
# [fusion|stacked_legacy] Romania s4  MAE=20.00 CI[18.1,22.0] r=0.653 a=0.20 | base 20.26 paper 18.70 -> within-noise
# [tbportals] split held_out=Moldova: train=3531 val=890 test=589 (train/val patients 3282/820).
# [fusion|stacked_legacy] Moldova s0  MAE=22.54 CI[20.8,24.2] r=0.821 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3541 val=880 test=589 (train/val patients 3282/820).
# [fusion|stacked_legacy] Moldova s1  MAE=21.54 CI[19.9,23.2] r=0.801 a=0.15 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3545 val=876 test=589 (train/val patients 3282/820).
# [fusion|stacked_legacy] Moldova s2  MAE=21.80 CI[20.3,23.3] r=0.794 a=0.25 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3539 val=882 test=589 (train/val patients 3282/820).
# [fusion|stacked_legacy] Moldova s3  MAE=21.44 CI[19.8,23.0] r=0.796 a=0.10 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Moldova: train=3522 val=899 test=589 (train/val patients 3282/820).
# [fusion|stacked_legacy] Moldova s4  MAE=22.21 CI[20.5,23.9] r=0.815 a=0.20 | base 26.16 paper 18.85 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3690 val=921 test=399 (train/val patients 3434/858).
# [fusion|stacked_legacy] Kazakhstan s0  MAE=17.14 CI[15.7,18.6] r=0.795 a=0.15 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3682 val=929 test=399 (train/val patients 3434/858).
# [fusion|stacked_legacy] Kazakhstan s1  MAE=16.42 CI[14.9,17.9] r=0.805 a=0.25 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|stacked_legacy] Kazakhstan s2  MAE=17.05 CI[15.6,18.5] r=0.786 a=0.20 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3691 val=920 test=399 (train/val patients 3434/858).
# [fusion|stacked_legacy] Kazakhstan s3  MAE=17.97 CI[16.5,19.5] r=0.764 a=0.10 | base 21.90 paper 19.62 -> BEATS
# [tbportals] split held_out=Kazakhstan: train=3689 val=922 test=399 (train/val patients 3434/858).
# [fusion|stacked_legacy] Kazakhstan s4  MAE=17.79 CI[16.4,19.2] r=0.784 a=0.15 | base 21.90 paper 19.62 -> BEATS
#
# [agentic] mean Timika MAE per rung x country (mode=fusion):
#   rung1_mse          Rom=19.83/0.66 Mol=22.55/0.79 Kaz=18.52/0.77
#   rung1_bmc          Rom=20.07/0.66 Mol=21.92/0.79 Kaz=17.32/0.78
#   rung2_tta          Rom=20.85/0.68 Mol=20.39/0.79 Kaz=19.27/0.76
#   rung3_retrieval    Rom=19.80/0.66 Mol=21.44/0.80 Kaz=17.39/0.79
#   rung5_moe          Rom=20.37/0.65 Mol=22.23/0.79 Kaz=17.44/0.77
#   rung6_conformal    Rom=19.88/0.66 Mol=22.34/0.80 Kaz=17.22/0.78
#   rung7_calibrate_lin Rom=20.02/0.65 Mol=22.47/0.79 Kaz=17.92/0.78
#   rung7_calibrate_iso Rom=19.93/0.65 Mol=22.59/0.79 Kaz=18.09/0.78
#   agentic_best       Rom=19.76/0.66 Mol=21.91/0.81 Kaz=17.28/0.79
#   agentic_v2_lin     Rom=19.83/0.66 Mol=22.25/0.80 Kaz=17.79/0.78
#   agentic_v2_iso     Rom=19.83/0.66 Mol=22.32/0.80 Kaz=18.00/0.78
#   agentic_best_tta   Rom=20.22/0.68 Mol=19.98/0.81 Kaz=18.84/0.77
#   rung4b_spatial_cavity Rom=19.43/0.69 Mol=21.44/0.81 Kaz=16.79/0.79
#   agentic_best_spatcav Rom=19.12/0.69 Mol=21.59/0.81 Kaz=16.74/0.80
#   stacked_legacy     Rom=19.76/0.66 Mol=21.91/0.81 Kaz=17.28/0.79
#
# [agentic] -> /kaggle/working/agentic_fusion/results_agentic_fusion.csv

# %% [markdown]
# ## 4 — Save (download → baseline_runs/agentic_runs/)

# %%
import os, shutil
src = f"{WORK}/agentic_{MODE}"
try: shutil.copy(FEATURES, f"{src}/{os.path.basename(FEATURES)}")
except Exception as e: print("primary cache copy skipped:", e)
try: shutil.copy(FEATURES_GRID, f"{src}/{os.path.basename(FEATURES_GRID)}")
except Exception as e: print("grid cache copy skipped:", e)
zip_path = shutil.make_archive(f"{WORK}/agentic_{MODE}", "zip", src)
print("Saved ->", zip_path)
print("Contents include: results_agentic_*.csv, preds_*.csv, heads/*.pt, features_*.npz")
# Out:
# Saved -> /kaggle/working/agentic_fusion.zip
# Contents include: results_agentic_*.csv, preds_*.csv, heads/*.pt, features_*.npz
